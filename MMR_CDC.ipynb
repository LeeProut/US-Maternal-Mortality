# %%
#import dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# #### Extract CSVs into DataFrames

# %%
# Name of the CSV file
CDC_file = 'Resources/2005-2019-MMR-US-CDC.csv'
ins_file = 'Resources/2019-US-health-insurance-coverage.csv'

# %%
# read csv files
cdc_df = pd.read_csv(CDC_file)
ins_df = pd.read_csv(ins_file, names=['Location', 'Employer', 'Non-Group', 'Medicaid', 'Medicare',
       'Military', 'Uninsured', 'Total', 'Footnotes'], header=0)

# %% [markdown]
# #### CDC MMR 2005-2019

# %%
cdc_df.head()
# Out:
#      State  State Code  Year  Deaths  Population  Crude Rate
# 0  Alabama           1  2005      12     2356423  Unreliable
# 1  Alabama           1  2006      10     2385480  Unreliable
# 2  Alabama           1  2015      12     2505795  Unreliable
# 3  Alabama           1  2016      35     2507714         1.4
# 4  Alabama           1  2017      41     2514911         1.6

# %%
#check column names
cdc_df.columns
# Out:
# Index(['State', 'State Code', 'Year', 'Deaths', 'Population', 'Crude Rate'], dtype='object')

# %%
#rename State column to delete extra characters
mmr_df = cdc_df.rename(columns={"ï»¿State": "State"})
mmr_df
# Out:
#          State  State Code  Year  Deaths  Population  Crude Rate
# 0      Alabama           1  2005      12     2356423  Unreliable
# 1      Alabama           1  2006      10     2385480  Unreliable
# 2      Alabama           1  2015      12     2505795  Unreliable
# 3      Alabama           1  2016      35     2507714         1.4
# 4      Alabama           1  2017      41     2514911         1.6
# ..         ...         ...   ...     ...         ...         ...
# 392  Wisconsin          55  2014      16     2898057  Unreliable
# 393  Wisconsin          55  2015      11     2903737  Unreliable
# 394  Wisconsin          55  2016      15     2905282  Unreliable
# 395  Wisconsin          55  2017      12     2912745  Unreliable
# 396  Wisconsin          55  2019      13     2925225  Unreliable
#
# [397 rows x 6 columns]

# %%
#check datatypes
mmr_df.dtypes
# Out:
# State         object
# State Code     int64
# Year           int64
# Deaths         int64
# Population     int64
# Crude Rate    object
# dtype: object

# %%
#look for missing values
mmr_df.count()
# Out:
# State         397
# State Code    397
# Year          397
# Deaths        397
# Population    397
# Crude Rate    397
# dtype: int64

# %%
#look at "unreliable" values in crude rate (these are used by the CDC for death counts < 20)
mmr_df ["Crude Rate"].value_counts()
# Out:
# Unreliable    160
# 0.7            41
# 0.6            38
# 0.5            33
# 0.8            22
# 0.4            18
# 0.9            17
# 1.1            17
# 1              15
# 1.2             8
# 1.4             7
# 1.3             5
# 1.5             4
# 1.6             3
# 2               2
# 0.3             2
# 1.7             2
# 1.8             1
# 1.9             1
# 2.3             1
# Name: Crude Rate, dtype: int64

# %%
#use groupby year to find total deaths for each year
year_totals = mmr_df.groupby(["Year"])

yearly_deaths = year_totals["Deaths"].sum()
yearly_deaths
# Out:
# Year
# 2005     640
# 2006     605
# 2007     666
# 2008     687
# 2009     841
# 2010     718
# 2011     832
# 2012     874
# 2013    1048
# 2014    1014
# 2015    1037
# 2016    1142
# 2017    1160
# 2018     874
# 2019    1010
# Name: Deaths, dtype: int64

# %%
# make a new dataframe with total deaths by year
year_summary_df = pd.DataFrame({"U.S. Maternal Deaths": yearly_deaths_df})
year_summary_df
# Out:
#       U.S. Maternal Deaths
# Year
# 2005                   640
# 2006                   605
# 2007                   666
# 2008                   687
# 2009                   841
# 2010                   718
# 2011                   832
# 2012                   874
# 2013                  1048
# 2014                  1014
# 2015                  1037
# 2016                  1142
# 2017                  1160
# 2018                   874
# 2019                  1010

# %%
#use groupby state to find total deaths for each state from 2005-2019
state_totals = mmr_df.groupby(["State"])

state_deaths_df = state_totals["Deaths"].sum()
state_deaths_df
# Out:
# State
# Alabama            176
# Arizona            240
# Arkansas           207
# California        1363
# Colorado            87
# Connecticut         25
# Florida            858
# Georgia            823
# Hawaii              12
# Idaho               10
# Illinois           465
# Indiana            388
# Iowa                35
# Kansas              86
# Kentucky           197
# Louisiana          331
# Maryland           294
# Massachusetts       47
# Michigan           509
# Minnesota          113
# Mississippi        188
# Missouri           329
# Nevada              11
# New Jersey         579
# New Mexico          45
# New York           949
# North Carolina     337
# Ohio               500
# Oklahoma           267
# Oregon              44
# Pennsylvania       489
# South Carolina     291
# Tennessee          263
# Texas             1809
# Utah                86
# Virginia           278
# Washington         242
# West Virginia       10
# Wisconsin          165
# Name: Deaths, dtype: int64

# %% [markdown]
# #### US Insurance Coverage 2019 : Health Insurance Coverage of Females 19-64 [source](https://www.kff.org/other/state-indicator/health-insurance-coverage-of-nonelderly-adult-females/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D)

# %%
ins_df.head()
# Out:
#          Location  Employer  Non-Group  Medicaid  Medicare Military  \
# 0   United States     0.607      0.079     0.165     0.020    0.015
# 1         Alabama     0.588      0.078     0.139     0.038    0.024
# 2          Alaska     0.591      0.041     0.170     0.013    0.065
# 3         Arizona     0.568      0.069     0.188     0.019    0.017
# 4        Arkansas     0.536      0.076     0.226     0.035    0.015
#
#    Uninsured  Total  Footnotes
# 0      0.114    1.0        1.0
# 1      0.133    1.0        NaN
# 2      0.119    1.0        NaN
# 3      0.138    1.0        NaN
# 4      0.113    1.0        NaN

# %%
# check datatypes
ins_df.dtypes
# Out:
# Location      object
# Employer     float64
# Non-Group    float64
# Medicaid     float64
# Medicare     float64
# Military      object
# Uninsured    float64
# Total        float64
# Footnotes    float64
# dtype: object

# %%
ins_df.head()
# Out:
#          Location  Employer  Non-Group  Medicaid  Medicare Military  \
# 0   United States     0.607      0.079     0.165     0.020    0.015
# 1         Alabama     0.588      0.078     0.139     0.038    0.024
# 2          Alaska     0.591      0.041     0.170     0.013    0.065
# 3         Arizona     0.568      0.069     0.188     0.019    0.017
# 4        Arkansas     0.536      0.076     0.226     0.035    0.015
#
#    Uninsured  Total  Footnotes
# 0      0.114    1.0        1.0
# 1      0.133    1.0        NaN
# 2      0.119    1.0        NaN
# 3      0.138    1.0        NaN
# 4      0.113    1.0        NaN

# %%
#check column names (previously found extra space preceding column names)
ins_df.columns
# Out:
# Index(['Location', 'Employer', 'Non-Group', 'Medicaid', 'Medicare', 'Military',
#        'Uninsured', 'Total', 'Footnotes'],
#       dtype='object')

# %%
ins_clean_df = ins_df.loc[ins_df["Military"]==" N/A"]
ins_clean_df
# Out:
#     Location  Employer  Non-Group  Medicaid  Medicare Military  Uninsured  \
# 46   Vermont     0.614      0.069     0.242     0.019      N/A      0.046
#
#     Total  Footnotes
# 46    1.0        NaN

# %%
#remove "N/A" from Military column 
ins_clean_df = ins_df.replace({" N/A": 0})
ins_clean_df
# Out:
#                  Location  Employer  Non-Group  Medicaid  Medicare Military  \
# 0           United States     0.607      0.079     0.165     0.020    0.015
# 1                 Alabama     0.588      0.078     0.139     0.038    0.024
# 2                  Alaska     0.591      0.041     0.170     0.013    0.065
# 3                 Arizona     0.568      0.069     0.188     0.019    0.017
# 4                Arkansas     0.536      0.076     0.226     0.035    0.015
# 5              California     0.570      0.087     0.225     0.013    0.009
# 6                Colorado     0.635      0.092     0.140     0.013    0.025
# 7             Connecticut     0.638      0.068     0.204     0.017    0.007
# 8                Delaware     0.635      0.064     0.184     0.020    0.021
# 9    District of Columbia     0.659      0.073     0.227     0.006    0.009
# 10                Florida     0.529      0.138     0.118     0.023    0.019
# 11                Georgia     0.604      0.075     0.105     0.023    0.023
# 12                 Hawaii     0.678      0.058     0.155     0.011    0.045
# 13                  Idaho     0.603      0.114     0.093     0.018    0.018
# 14               Illinois     0.653      0.070     0.162     0.019    0.006
# 15                Indiana     0.641      0.061     0.162     0.024    0.010
# 16                   Iowa     0.672      0.065     0.186     0.014    0.009
# 17                 Kansas     0.660      0.075     0.098     0.020    0.022
# 18               Kentucky     0.577      0.054     0.243     0.035    0.014
# 19              Louisiana     0.518      0.067     0.274     0.026    0.014
# 20                  Maine     0.600      0.084     0.176     0.027    0.015
# 21               Maryland     0.658      0.071     0.160     0.019    0.021
# 22          Massachusetts     0.667      0.071     0.213     0.013    0.005
# 23               Michigan     0.623      0.073     0.208     0.024    0.006
# 24              Minnesota     0.699      0.066     0.160     0.015    0.006
# 25            Mississippi     0.542      0.067     0.165     0.028    0.020
# 26               Missouri     0.643      0.074     0.108     0.031    0.014
# 27                Montana     0.551      0.113     0.181     0.028    0.016
# 28               Nebraska     0.686      0.094     0.083     0.018    0.018
# 29                 Nevada     0.596      0.069     0.160     0.019    0.017
# 30          New Hampshire     0.689      0.074     0.117     0.028    0.012
# 31             New Jersey     0.668      0.071     0.138     0.021    0.005
# 32             New Mexico     0.472      0.056     0.311     0.023    0.019
# 33               New York     0.612      0.071     0.237     0.017    0.004
# 34         North Carolina     0.582      0.094     0.123     0.024    0.027
# 35           North Dakota     0.662      0.120     0.105     0.014    0.019
# 36                   Ohio     0.644      0.053     0.194     0.024    0.007
# 37               Oklahoma     0.566      0.077     0.098     0.030    0.023
# 38                 Oregon     0.606      0.083     0.198     0.019    0.009
# 39           Pennsylvania     0.643      0.071     0.188     0.020    0.009
# 40           Rhode Island     0.642      0.081     0.193     0.023    0.007
# 41         South Carolina     0.583      0.086     0.139     0.032    0.024
# 42           South Dakota     0.648      0.106     0.084     0.017    0.024
# 43              Tennessee     0.588      0.077     0.164     0.026    0.019
# 44                  Texas     0.574      0.076     0.083     0.018    0.017
# 45                   Utah     0.683      0.108     0.067     0.008    0.014
# 46                Vermont     0.614      0.069     0.242     0.019        0
# 47               Virginia     0.657      0.070     0.107     0.024    0.049
# 48             Washington     0.640      0.070     0.169     0.017    0.022
# 49          West Virginia     0.566      0.035     0.270     0.036    0.012
# 50              Wisconsin     0.691      0.076     0.145     0.013    0.008
# 51                Wyoming     0.604      0.098     0.097     0.014    0.019
# 52            Puerto Rico     0.306      0.107     0.451     0.037    0.005
#
#     Uninsured  Total  Footnotes
# 0       0.114    1.0        1.0
# 1       0.133    1.0        NaN
# 2       0.119    1.0        NaN
# 3       0.138    1.0        NaN
# 4       0.113    1.0        NaN
# 5       0.095    1.0        NaN
# 6       0.095    1.0        NaN
# 7       0.066    1.0        NaN
# 8       0.075    1.0        NaN
# 9       0.027    1.0        NaN
# 10      0.173    1.0        NaN
# 11      0.170    1.0        NaN
# 12      0.054    1.0        NaN
# 13      0.155    1.0        NaN
# 14      0.089    1.0        NaN
# 15      0.102    1.0        NaN
# 16      0.054    1.0        NaN
# 17      0.126    1.0        NaN
# 18      0.077    1.0        NaN
# 19      0.101    1.0        NaN
# 20      0.098    1.0        NaN
# 21      0.071    1.0        NaN
# 22      0.031    1.0        NaN
# 23      0.067    1.0        NaN
# 24      0.055    1.0        NaN
# 25      0.178    1.0        NaN
# 26      0.130    1.0        NaN
# 27      0.112    1.0        NaN
# 28      0.101    1.0        NaN
# 29      0.139    1.0        NaN
# 30      0.080    1.0        NaN
# 31      0.098    1.0        NaN
# 32      0.118    1.0        NaN
# 33      0.059    1.0        NaN
# 34      0.149    1.0        NaN
# 35      0.079    1.0        NaN
# 36      0.078    1.0        NaN
# 37      0.206    1.0        NaN
# 38      0.086    1.0        NaN
# 39      0.069    1.0        NaN
# 40      0.054    1.0        NaN
# 41      0.136    1.0        NaN
# 42      0.121    1.0        NaN
# 43      0.125    1.0        NaN
# 44      0.232    1.0        NaN
# 45      0.119    1.0        NaN
# 46      0.046    1.0        NaN
# 47      0.094    1.0        NaN
# 48      0.082    1.0        NaN
# 49      0.080    1.0        NaN
# 50      0.067    1.0        NaN
# 51      0.167    1.0        NaN
# 52      0.094    1.0        NaN

# %%
# check datatypes
ins_clean_df.dtypes
# Out:
# Location      object
# Employer     float64
# Non-Group    float64
# Medicaid     float64
# Medicare     float64
# Military     float64
# Uninsured    float64
# Total        float64
# Footnotes    float64
# dtype: object

# %%
# use pd.to_numeric() method to convert the datatype of the Military column from object to float
ins_clean_df["Military"] = pd.to_numeric(ins_clean_df["Military"])

# %%
# verify data types 
ins_clean_df.dtypes
# Out:
# Location      object
# Employer     float64
# Non-Group    float64
# Medicaid     float64
# Medicare     float64
# Military     float64
# Uninsured    float64
# Total        float64
# Footnotes    float64
# dtype: object

# %%
#convert values to percentages and then use .style.format({"column name" : "{:,.2f}%"})
employer_per = ins_clean_df["Employer"] * 100
employer_per

non_group_per = ins_clean_df["Non-Group"] * 100
non_group_per

medicaid_per = ins_clean_df["Medicaid"] * 100
medicaid_per

medicare_per = ins_clean_df["Medicare"] * 100
medicare_per

military_per = ins_clean_df["Military"] * 100
military_per

uninsured_per = ins_clean_df["Uninsured"] * 100
uninsured_per

total_per = ins_clean_df["Total"] * 100
total_per
# Out:
# 0     100.0
# 1     100.0
# 2     100.0
# 3     100.0
# 4     100.0
# 5     100.0
# 6     100.0
# 7     100.0
# 8     100.0
# 9     100.0
# 10    100.0
# 11    100.0
# 12    100.0
# 13    100.0
# 14    100.0
# 15    100.0
# 16    100.0
# 17    100.0
# 18    100.0
# 19    100.0
# 20    100.0
# 21    100.0
# 22    100.0
# 23    100.0
# 24    100.0
# 25    100.0
# 26    100.0
# 27    100.0
# 28    100.0
# 29    100.0
# 30    100.0
# 31    100.0
# 32    100.0
# 33    100.0
# 34    100.0
# 35    100.0
# 36    100.0
# 37    100.0
# 38    100.0
# 39    100.0
# 40    100.0
# 41    100.0
# 42    100.0
# 43    100.0
# 44    100.0
# 45    100.0
# 46    100.0
# 47    100.0
# 48    100.0
# 49    100.0
# 50    100.0
# 51    100.0
# 52    100.0
# Name: Total, dtype: float64

# %%
# assign locations to list for new dataframe
locations = ins_clean_df["Location"]
locations
# Out:
# 0             United States
# 1                   Alabama
# 2                    Alaska
# 3                   Arizona
# 4                  Arkansas
# 5                California
# 6                  Colorado
# 7               Connecticut
# 8                  Delaware
# 9      District of Columbia
# 10                  Florida
# 11                  Georgia
# 12                   Hawaii
# 13                    Idaho
# 14                 Illinois
# 15                  Indiana
# 16                     Iowa
# 17                   Kansas
# 18                 Kentucky
# 19                Louisiana
# 20                    Maine
# 21                 Maryland
# 22            Massachusetts
# 23                 Michigan
# 24                Minnesota
# 25              Mississippi
# 26                 Missouri
# 27                  Montana
# 28                 Nebraska
# 29                   Nevada
# 30            New Hampshire
# 31               New Jersey
# 32               New Mexico
# 33                 New York
# 34           North Carolina
# 35             North Dakota
# 36                     Ohio
# 37                 Oklahoma
# 38                   Oregon
# 39             Pennsylvania
# 40             Rhode Island
# 41           South Carolina
# 42             South Dakota
# 43                Tennessee
# 44                    Texas
# 45                     Utah
# 46                  Vermont
# 47                 Virginia
# 48               Washington
# 49            West Virginia
# 50                Wisconsin
# 51                  Wyoming
# 52              Puerto Rico
# Name: Location, dtype: object

# %%
# make a new dataframe with percentages and without the footnotes column
us_ins_2019_df = pd.DataFrame({'Location': locations,
                               'Year': '2019',
                               'Employer': employer_per, 
                               'Non-Group': non_group_per,
                               'Medicaid': medicaid_per,
                               'Medicare': medicare_per, 
                               'Military': military_per,
                               'Uninsured': uninsured_per, 
                               'Total': total_per})
us_ins_2019_df
# Out:
#                  Location  Year  Employer  Non-Group  Medicaid  Medicare  \
# 0           United States  2019      60.7        7.9      16.5       2.0
# 1                 Alabama  2019      58.8        7.8      13.9       3.8
# 2                  Alaska  2019      59.1        4.1      17.0       1.3
# 3                 Arizona  2019      56.8        6.9      18.8       1.9
# 4                Arkansas  2019      53.6        7.6      22.6       3.5
# 5              California  2019      57.0        8.7      22.5       1.3
# 6                Colorado  2019      63.5        9.2      14.0       1.3
# 7             Connecticut  2019      63.8        6.8      20.4       1.7
# 8                Delaware  2019      63.5        6.4      18.4       2.0
# 9    District of Columbia  2019      65.9        7.3      22.7       0.6
# 10                Florida  2019      52.9       13.8      11.8       2.3
# 11                Georgia  2019      60.4        7.5      10.5       2.3
# 12                 Hawaii  2019      67.8        5.8      15.5       1.1
# 13                  Idaho  2019      60.3       11.4       9.3       1.8
# 14               Illinois  2019      65.3        7.0      16.2       1.9
# 15                Indiana  2019      64.1        6.1      16.2       2.4
# 16                   Iowa  2019      67.2        6.5      18.6       1.4
# 17                 Kansas  2019      66.0        7.5       9.8       2.0
# 18               Kentucky  2019      57.7        5.4      24.3       3.5
# 19              Louisiana  2019      51.8        6.7      27.4       2.6
# 20                  Maine  2019      60.0        8.4      17.6       2.7
# 21               Maryland  2019      65.8        7.1      16.0       1.9
# 22          Massachusetts  2019      66.7        7.1      21.3       1.3
# 23               Michigan  2019      62.3        7.3      20.8       2.4
# 24              Minnesota  2019      69.9        6.6      16.0       1.5
# 25            Mississippi  2019      54.2        6.7      16.5       2.8
# 26               Missouri  2019      64.3        7.4      10.8       3.1
# 27                Montana  2019      55.1       11.3      18.1       2.8
# 28               Nebraska  2019      68.6        9.4       8.3       1.8
# 29                 Nevada  2019      59.6        6.9      16.0       1.9
# 30          New Hampshire  2019      68.9        7.4      11.7       2.8
# 31             New Jersey  2019      66.8        7.1      13.8       2.1
# 32             New Mexico  2019      47.2        5.6      31.1       2.3
# 33               New York  2019      61.2        7.1      23.7       1.7
# 34         North Carolina  2019      58.2        9.4      12.3       2.4
# 35           North Dakota  2019      66.2       12.0      10.5       1.4
# 36                   Ohio  2019      64.4        5.3      19.4       2.4
# 37               Oklahoma  2019      56.6        7.7       9.8       3.0
# 38                 Oregon  2019      60.6        8.3      19.8       1.9
# 39           Pennsylvania  2019      64.3        7.1      18.8       2.0
# 40           Rhode Island  2019      64.2        8.1      19.3       2.3
# 41         South Carolina  2019      58.3        8.6      13.9       3.2
# 42           South Dakota  2019      64.8       10.6       8.4       1.7
# 43              Tennessee  2019      58.8        7.7      16.4       2.6
# 44                  Texas  2019      57.4        7.6       8.3       1.8
# 45                   Utah  2019      68.3       10.8       6.7       0.8
# 46                Vermont  2019      61.4        6.9      24.2       1.9
# 47               Virginia  2019      65.7        7.0      10.7       2.4
# 48             Washington  2019      64.0        7.0      16.9       1.7
# 49          West Virginia  2019      56.6        3.5      27.0       3.6
# 50              Wisconsin  2019      69.1        7.6      14.5       1.3
# 51                Wyoming  2019      60.4        9.8       9.7       1.4
# 52            Puerto Rico  2019      30.6       10.7      45.1       3.7
#
#     Military  Uninsured  Total
# 0        1.5       11.4  100.0
# 1        2.4       13.3  100.0
# 2        6.5       11.9  100.0
# 3        1.7       13.8  100.0
# 4        1.5       11.3  100.0
# 5        0.9        9.5  100.0
# 6        2.5        9.5  100.0
# 7        0.7        6.6  100.0
# 8        2.1        7.5  100.0
# 9        0.9        2.7  100.0
# 10       1.9       17.3  100.0
# 11       2.3       17.0  100.0
# 12       4.5        5.4  100.0
# 13       1.8       15.5  100.0
# 14       0.6        8.9  100.0
# 15       1.0       10.2  100.0
# 16       0.9        5.4  100.0
# 17       2.2       12.6  100.0
# 18       1.4        7.7  100.0
# 19       1.4       10.1  100.0
# 20       1.5        9.8  100.0
# 21       2.1        7.1  100.0
# 22       0.5        3.1  100.0
# 23       0.6        6.7  100.0
# 24       0.6        5.5  100.0
# 25       2.0       17.8  100.0
# 26       1.4       13.0  100.0
# 27       1.6       11.2  100.0
# 28       1.8       10.1  100.0
# 29       1.7       13.9  100.0
# 30       1.2        8.0  100.0
# 31       0.5        9.8  100.0
# 32       1.9       11.8  100.0
# 33       0.4        5.9  100.0
# 34       2.7       14.9  100.0
# 35       1.9        7.9  100.0
# 36       0.7        7.8  100.0
# 37       2.3       20.6  100.0
# 38       0.9        8.6  100.0
# 39       0.9        6.9  100.0
# 40       0.7        5.4  100.0
# 41       2.4       13.6  100.0
# 42       2.4       12.1  100.0
# 43       1.9       12.5  100.0
# 44       1.7       23.2  100.0
# 45       1.4       11.9  100.0
# 46       0.0        4.6  100.0
# 47       4.9        9.4  100.0
# 48       2.2        8.2  100.0
# 49       1.2        8.0  100.0
# 50       0.8        6.7  100.0
# 51       1.9       16.7  100.0
# 52       0.5        9.4  100.0

# %% [markdown]
# #### US insurance coverage 2013 : Health Insurance Coverage of Females 19-64 [source](https://www.kff.org/other/state-indicator/health-insurance-coverage-of-nonelderly-adult-females/?currentTimeframe=6&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D)

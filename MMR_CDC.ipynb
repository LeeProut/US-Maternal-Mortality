# %%
#import dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# #### Extract CSVs into DataFrames

# %%
# Name of the CSV file
#CDC data 
CDC_file = 'Resources/2005-2019-MMR-US-CDC.csv'

# insurance files by year
ins_file_2019 = 'Resources/2019-US-health-insurance-coverage.csv'
ins_file_2013 = 'Resources/2013_US_health_insurance.csv'
ins_file_2011 = 'Resources/2011_US_ins_coverage.csv'
ins_file_2009 = 'Resources/2009_US_ins_coverage.csv'

# %%
# read csv files
cdc_df = pd.read_csv(CDC_file)
ins_df = pd.read_csv(ins_file_2019, names=['Location', 'Employer', 'Non-Group', 'Medicaid', 'Medicare',
       'Military', 'Uninsured', 'Total', 'Footnotes'], header=0)
ins_df_2013 = pd.read_csv(ins_file_2013, names=['Location', 'Employer', 'Non-Group', 'Medicaid', 'Medicare',
       'Military', 'Uninsured', 'Total', 'Footnotes'], header=0)
ins_df_2011 = pd.read_csv(ins_file_2011, names=['Location', 'Employer', 'Non-Group', 'Medicaid', 'Medicare',
       'Military', 'Uninsured', 'Total', 'Footnotes'], header=0)
ins_df_2009 = pd.read_csv(ins_file_2009, names=['Location', 'Employer', 'Non-Group', 'Medicaid', 'Medicare',
       'Military', 'Uninsured', 'Total', 'Footnotes'], header=0)

# %% [markdown]
# #### CDC MMR 2005-2019

# %%
cdc_df.head()
# Out:
#      State  State Code  Year  Deaths  Population  Crude Rate
# 0  Alabama           1  2005      12     2356423  Unreliable
# 1  Alabama           1  2006      10     2385480  Unreliable
# 2  Alabama           1  2015      12     2505795  Unreliable
# 3  Alabama           1  2016      35     2507714         1.4
# 4  Alabama           1  2017      41     2514911         1.6

# %%
#check column names
cdc_df.columns
# Out:
# Index(['State', 'State Code', 'Year', 'Deaths', 'Population', 'Crude Rate'], dtype='object')

# %%
#rename State column to delete extra characters
mmr_df = cdc_df.rename(columns={"ï»¿State": "State"})
mmr_df
# Out:
#          State  State Code  Year  Deaths  Population  Crude Rate
# 0      Alabama           1  2005      12     2356423  Unreliable
# 1      Alabama           1  2006      10     2385480  Unreliable
# 2      Alabama           1  2015      12     2505795  Unreliable
# 3      Alabama           1  2016      35     2507714         1.4
# 4      Alabama           1  2017      41     2514911         1.6
# ..         ...         ...   ...     ...         ...         ...
# 392  Wisconsin          55  2014      16     2898057  Unreliable
# 393  Wisconsin          55  2015      11     2903737  Unreliable
# 394  Wisconsin          55  2016      15     2905282  Unreliable
# 395  Wisconsin          55  2017      12     2912745  Unreliable
# 396  Wisconsin          55  2019      13     2925225  Unreliable
#
# [397 rows x 6 columns]

# %%
#check datatypes
mmr_df.dtypes
# Out:
# State         object
# State Code     int64
# Year           int64
# Deaths         int64
# Population     int64
# Crude Rate    object
# dtype: object

# %%
#look for missing values
mmr_df.count()
# Out:
# State         397
# State Code    397
# Year          397
# Deaths        397
# Population    397
# Crude Rate    397
# dtype: int64

# %%
#look at "unreliable" values in crude rate (these are used by the CDC for death counts < 20)
mmr_df ["Crude Rate"].value_counts()
# Out:
# Unreliable    160
# 0.7            41
# 0.6            38
# 0.5            33
# 0.8            22
# 0.4            18
# 0.9            17
# 1.1            17
# 1              15
# 1.2             8
# 1.4             7
# 1.3             5
# 1.5             4
# 1.6             3
# 2               2
# 0.3             2
# 1.7             2
# 1.8             1
# 1.9             1
# 2.3             1
# Name: Crude Rate, dtype: int64

# %%
#use groupby year to find total deaths for each year
year_totals = mmr_df.groupby(["Year"])

yearly_deaths = year_totals["Deaths"].sum()
yearly_deaths
# Out:
# Year
# 2005     640
# 2006     605
# 2007     666
# 2008     687
# 2009     841
# 2010     718
# 2011     832
# 2012     874
# 2013    1048
# 2014    1014
# 2015    1037
# 2016    1142
# 2017    1160
# 2018     874
# 2019    1010
# Name: Deaths, dtype: int64

# %%
# make a new dataframe with total deaths by year
year_summary_df = pd.DataFrame({"U.S. Maternal Deaths": yearly_deaths_df})
year_summary_df
# Out:
#       U.S. Maternal Deaths
# Year
# 2005                   640
# 2006                   605
# 2007                   666
# 2008                   687
# 2009                   841
# 2010                   718
# 2011                   832
# 2012                   874
# 2013                  1048
# 2014                  1014
# 2015                  1037
# 2016                  1142
# 2017                  1160
# 2018                   874
# 2019                  1010

# %%
#use groupby state to find total deaths for each state from 2005-2019
state_totals = mmr_df.groupby(["State"])

state_deaths_df = state_totals["Deaths"].sum()
state_deaths_df
# Out:
# State
# Alabama            176
# Arizona            240
# Arkansas           207
# California        1363
# Colorado            87
# Connecticut         25
# Florida            858
# Georgia            823
# Hawaii              12
# Idaho               10
# Illinois           465
# Indiana            388
# Iowa                35
# Kansas              86
# Kentucky           197
# Louisiana          331
# Maryland           294
# Massachusetts       47
# Michigan           509
# Minnesota          113
# Mississippi        188
# Missouri           329
# Nevada              11
# New Jersey         579
# New Mexico          45
# New York           949
# North Carolina     337
# Ohio               500
# Oklahoma           267
# Oregon              44
# Pennsylvania       489
# South Carolina     291
# Tennessee          263
# Texas             1809
# Utah                86
# Virginia           278
# Washington         242
# West Virginia       10
# Wisconsin          165
# Name: Deaths, dtype: int64

# %% [markdown]
# #### US Insurance Coverage 2019 : Health Insurance Coverage of Females 19-64 [source](https://www.kff.org/other/state-indicator/health-insurance-coverage-of-nonelderly-adult-females/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D)

# %%
ins_df.head()
# Out:
#          Location  Employer  Non-Group  Medicaid  Medicare Military  \
# 0   United States     0.607      0.079     0.165     0.020    0.015
# 1         Alabama     0.588      0.078     0.139     0.038    0.024
# 2          Alaska     0.591      0.041     0.170     0.013    0.065
# 3         Arizona     0.568      0.069     0.188     0.019    0.017
# 4        Arkansas     0.536      0.076     0.226     0.035    0.015
#
#    Uninsured  Total  Footnotes
# 0      0.114    1.0        1.0
# 1      0.133    1.0        NaN
# 2      0.119    1.0        NaN
# 3      0.138    1.0        NaN
# 4      0.113    1.0        NaN

# %%
# check datatypes
ins_df.dtypes
# Out:
# Location      object
# Employer     float64
# Non-Group    float64
# Medicaid     float64
# Medicare     float64
# Military      object
# Uninsured    float64
# Total        float64
# Footnotes    float64
# dtype: object

# %%
ins_df.head()
# Out:
#          Location  Employer  Non-Group  Medicaid  Medicare Military  \
# 0   United States     0.607      0.079     0.165     0.020    0.015
# 1         Alabama     0.588      0.078     0.139     0.038    0.024
# 2          Alaska     0.591      0.041     0.170     0.013    0.065
# 3         Arizona     0.568      0.069     0.188     0.019    0.017
# 4        Arkansas     0.536      0.076     0.226     0.035    0.015
#
#    Uninsured  Total  Footnotes
# 0      0.114    1.0        1.0
# 1      0.133    1.0        NaN
# 2      0.119    1.0        NaN
# 3      0.138    1.0        NaN
# 4      0.113    1.0        NaN

# %%
# check column names (previously found extra space preceding column names)
ins_df.columns
# Out:
# Index(['Location', 'Employer', 'Non-Group', 'Medicaid', 'Medicare', 'Military',
#        'Uninsured', 'Total', 'Footnotes'],
#       dtype='object')

# %%
ins_clean_df = ins_df.loc[ins_df["Military"]==" N/A"]
ins_clean_df
# Out:
#     Location  Employer  Non-Group  Medicaid  Medicare Military  Uninsured  \
# 46   Vermont     0.614      0.069     0.242     0.019      N/A      0.046
#
#     Total  Footnotes
# 46    1.0        NaN

# %%
#remove "N/A" from Military column 
ins_clean_df = ins_df.replace({" N/A": 0})
ins_clean_df.head()
# Out:
#          Location  Employer  Non-Group  Medicaid  Medicare Military  \
# 0   United States     0.607      0.079     0.165     0.020    0.015
# 1         Alabama     0.588      0.078     0.139     0.038    0.024
# 2          Alaska     0.591      0.041     0.170     0.013    0.065
# 3         Arizona     0.568      0.069     0.188     0.019    0.017
# 4        Arkansas     0.536      0.076     0.226     0.035    0.015
#
#    Uninsured  Total  Footnotes
# 0      0.114    1.0        1.0
# 1      0.133    1.0        NaN
# 2      0.119    1.0        NaN
# 3      0.138    1.0        NaN
# 4      0.113    1.0        NaN

# %%
# check datatypes
ins_clean_df.dtypes
# Out:
# Location      object
# Employer     float64
# Non-Group    float64
# Medicaid     float64
# Medicare     float64
# Military      object
# Uninsured    float64
# Total        float64
# Footnotes    float64
# dtype: object

# %%
# use pd.to_numeric() method to convert the datatype of the Military column from object to float
ins_clean_df["Military"] = pd.to_numeric(ins_clean_df["Military"])

# %%
# verify data types 
ins_clean_df.dtypes
# Out:
# Location      object
# Employer     float64
# Non-Group    float64
# Medicaid     float64
# Medicare     float64
# Military     float64
# Uninsured    float64
# Total        float64
# Footnotes    float64
# dtype: object

# %%
#convert values to percentages and then use .style.format({"column name" : "{:,.2f}%"})
employer_per = ins_clean_df["Employer"] * 100
employer_per

non_group_per = ins_clean_df["Non-Group"] * 100
non_group_per

medicaid_per = ins_clean_df["Medicaid"] * 100
medicaid_per

medicare_per = ins_clean_df["Medicare"] * 100
medicare_per

military_per = ins_clean_df["Military"] * 100
military_per

uninsured_per = ins_clean_df["Uninsured"] * 100
uninsured_per

total_per = ins_clean_df["Total"] * 100
total_per.head()
# Out:
# 0    100.0
# 1    100.0
# 2    100.0
# 3    100.0
# 4    100.0
# Name: Total, dtype: float64

# %%
# assign locations to list for new dataframe
locations = ins_clean_df["Location"]
locations.head()
# Out:
# 0     United States
# 1           Alabama
# 2            Alaska
# 3           Arizona
# 4          Arkansas
# Name: Location, dtype: object

# %%
# make a new dataframe with percentages and without the footnotes column
us_ins_2019_df = pd.DataFrame({'Location': locations,
                               'Year': '2019',
                               'Employer': employer_per, 
                               'Non-Group': non_group_per,
                               'Medicaid': medicaid_per,
                               'Medicare': medicare_per, 
                               'Military': military_per,
                               'Uninsured': uninsured_per, 
                               'Total': total_per})
us_ins_2019_df.head()
# Out:
#          Location  Year  Employer  Non-Group  Medicaid  Medicare  Military  \
# 0   United States  2019      60.7        7.9      16.5       2.0       1.5
# 1         Alabama  2019      58.8        7.8      13.9       3.8       2.4
# 2          Alaska  2019      59.1        4.1      17.0       1.3       6.5
# 3         Arizona  2019      56.8        6.9      18.8       1.9       1.7
# 4        Arkansas  2019      53.6        7.6      22.6       3.5       1.5
#
#    Uninsured  Total
# 0       11.4  100.0
# 1       13.3  100.0
# 2       11.9  100.0
# 3       13.8  100.0
# 4       11.3  100.0

# %% [markdown]
# #### US insurance coverage 2013 : Health Insurance Coverage of Females 19-64 [source](https://www.kff.org/other/state-indicator/health-insurance-coverage-of-nonelderly-adult-females/?currentTimeframe=6&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D)

# %%
ins_df_2013.head()
# Out:
#         Location  Employer  Non-Group  Medicaid  Medicare  Military  \
# 0  United States     0.581      0.067     0.129     0.020     0.016
# 1        Alabama     0.555      0.068     0.125     0.041     0.021
# 2         Alaska     0.600      0.037     0.075       NaN     0.057
# 3        Arizona     0.527      0.072     0.151     0.018     0.018
# 4       Arkansas     0.528      0.063     0.123     0.037     0.020
#
#    Uninsured  Total  Footnotes
# 0      0.187    1.0        1.0
# 1      0.190    1.0        NaN
# 2      0.223    1.0        NaN
# 3      0.213    1.0        NaN
# 4      0.229    1.0        NaN

# %%
# check datatypes
ins_df_2013.dtypes
# Out:
# Location      object
# Employer     float64
# Non-Group    float64
# Medicaid     float64
# Medicare     float64
# Military     float64
# Uninsured    float64
# Total        float64
# Footnotes    float64
# dtype: object

# %%
#check column names (previously found extra space preceding column names)
ins_df_2013.columns
# Out:
# Index(['Location', 'Employer', 'Non-Group', 'Medicaid', 'Medicare', 'Military',
#        'Uninsured', 'Total', 'Footnotes'],
#       dtype='object')

# %%
clean_ins_df_2013 = ins_df_2013.fillna(0)
clean_ins_df_2013.head()
# Out:
#         Location  Employer  Non-Group  Medicaid  Medicare  Military  \
# 0  United States     0.581      0.067     0.129     0.020     0.016
# 1        Alabama     0.555      0.068     0.125     0.041     0.021
# 2         Alaska     0.600      0.037     0.075     0.000     0.057
# 3        Arizona     0.527      0.072     0.151     0.018     0.018
# 4       Arkansas     0.528      0.063     0.123     0.037     0.020
#
#    Uninsured  Total  Footnotes
# 0      0.187    1.0        1.0
# 1      0.190    1.0        0.0
# 2      0.223    1.0        0.0
# 3      0.213    1.0        0.0
# 4      0.229    1.0        0.0

# %%
#convert values to percentages and then use .style.format({"column name" : "{:,.2f}%"})
employer_per_2013 = clean_ins_df_2013["Employer"] * 100
employer_per_2013

non_group_per_2013 = clean_ins_df_2013["Non-Group"] * 100
non_group_per_2013

medicaid_per_2013 = clean_ins_df_2013["Medicaid"] * 100
medicaid_per_2013

medicare_per_2013 = clean_ins_df_2013["Medicare"] * 100
medicare_per_2013

military_per_2013 = clean_ins_df_2013["Military"] * 100
military_per_2013

uninsured_per_2013 = clean_ins_df_2013["Uninsured"] * 100
uninsured_per_2013

total_per_2013 = clean_ins_df_2013["Total"] * 100
total_per_2013.head()
# Out:
# 0    100.0
# 1    100.0
# 2    100.0
# 3    100.0
# 4    100.0
# Name: Total, dtype: float64

# %%
# assign locations to list for new dataframe
locations_2013 = clean_ins_df_2013["Location"]
locations_2013.head()
# Out:
# 0    United States
# 1          Alabama
# 2           Alaska
# 3          Arizona
# 4         Arkansas
# Name: Location, dtype: object

# %%
# make a new dataframe with percentages and without the footnotes column
us_ins_2013_df = pd.DataFrame({'Location': locations_2013,
                               'Year': '2013',
                               'Employer': employer_per_2013, 
                               'Non-Group': non_group_per_2013,
                               'Medicaid': medicaid_per_2013,
                               'Medicare': medicare_per_2013, 
                               'Military': military_per_2013,
                               'Uninsured': uninsured_per_2013, 
                               'Total': total_per_2013})
us_ins_2013_df.head()
# Out:
#         Location  Year  Employer  Non-Group  Medicaid  Medicare  Military  \
# 0  United States  2013      58.1        6.7      12.9       2.0       1.6
# 1        Alabama  2013      55.5        6.8      12.5       4.1       2.1
# 2         Alaska  2013      60.0        3.7       7.5       0.0       5.7
# 3        Arizona  2013      52.7        7.2      15.1       1.8       1.8
# 4       Arkansas  2013      52.8        6.3      12.3       3.7       2.0
#
#    Uninsured  Total
# 0       18.7  100.0
# 1       19.0  100.0
# 2       22.3  100.0
# 3       21.3  100.0
# 4       22.9  100.0

# %% [markdown]
# #### US insurance coverage 2009 : Health Insurance Coverage of Females 19-64 [source](https://www.kff.org/other/state-indicator/health-insurance-coverage-of-nonelderly-adult-females/?currentTimeframe=10&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D)

# %%
ins_df_2009.head()
# Out:
#         Location  Employer  Non-Group  Medicaid  Medicare  Military  \
# 0  United States     0.603      0.066     0.115     0.019     0.014
# 1        Alabama     0.586      0.061     0.114     0.035     0.022
# 2         Alaska     0.567      0.042     0.101       NaN     0.056
# 3        Arizona     0.538      0.069     0.155     0.020     0.017
# 4       Arkansas     0.541      0.058     0.118     0.036     0.015
#
#    Uninsured  Total  Footnotes
# 0      0.183    1.0        1.0
# 1      0.182    1.0        NaN
# 2      0.227    1.0        NaN
# 3      0.201    1.0        NaN
# 4      0.231    1.0        NaN

# %%
# check datatypes
ins_df_2009.dtypes
# Out:
# Location      object
# Employer     float64
# Non-Group    float64
# Medicaid     float64
# Medicare     float64
# Military     float64
# Uninsured    float64
# Total        float64
# Footnotes    float64
# dtype: object

# %%
# check column names
ins_df_2009.columns
# Out:
# Index(['Location', 'Employer', 'Non-Group', 'Medicaid', 'Medicare', 'Military',
#        'Uninsured', 'Total', 'Footnotes'],
#       dtype='object')

# %%
# adjust NaN values to 0 with .fillna(0)
ins_df_2009_clean = ins_df_2009.fillna(0)
ins_df_2009_clean.head()
# Out:
#         Location  Employer  Non-Group  Medicaid  Medicare  Military  \
# 0  United States     0.603      0.066     0.115     0.019     0.014
# 1        Alabama     0.586      0.061     0.114     0.035     0.022
# 2         Alaska     0.567      0.042     0.101     0.000     0.056
# 3        Arizona     0.538      0.069     0.155     0.020     0.017
# 4       Arkansas     0.541      0.058     0.118     0.036     0.015
#
#    Uninsured  Total  Footnotes
# 0      0.183    1.0        1.0
# 1      0.182    1.0        0.0
# 2      0.227    1.0        0.0
# 3      0.201    1.0        0.0
# 4      0.231    1.0        0.0

# %%
#convert values to percentages 

employer_per_2009 = ins_df_2009_clean["Employer"] * 100
employer_per_2009

non_group_per_2009 = ins_df_2009_clean["Non-Group"] * 100
non_group_per_2009

medicaid_per_2009 = ins_df_2009_clean["Medicaid"] * 100
medicaid_per_2009

medicare_per_2009 = ins_df_2009_clean["Medicare"] * 100
medicare_per_2009

military_per_2009 = ins_df_2009_clean["Military"] * 100
military_per_2009

uninsured_per_2009 = ins_df_2009_clean["Uninsured"] * 100
uninsured_per_2009

total_per_2009 = ins_df_2009_clean["Total"] * 100
total_per_2009.head()
# Out:
# 0    100.0
# 1    100.0
# 2    100.0
# 3    100.0
# 4    100.0
# Name: Total, dtype: float64

# %%
locations_2009 = ins_df_2009_clean["Location"]
locations_2009.head()
# Out:
# 0    United States
# 1          Alabama
# 2           Alaska
# 3          Arizona
# 4         Arkansas
# Name: Location, dtype: object

# %%
# make a new dataframe with percentages and without the footnotes column
us_ins_2009_df = pd.DataFrame({'Location': locations_2009,
                               'Year': '2009',
                               'Employer': employer_per_2009, 
                               'Non-Group': non_group_per_2009,
                               'Medicaid': medicaid_per_2009,
                               'Medicare': medicare_per_2009, 
                               'Military': military_per_2009,
                               'Uninsured': uninsured_per_2009, 
                               'Total': total_per_2009})
us_ins_2009_df.head()
# Out:
#         Location  Year  Employer  Non-Group  Medicaid  Medicare  Military  \
# 0  United States  2009      60.3        6.6      11.5       1.9       1.4
# 1        Alabama  2009      58.6        6.1      11.4       3.5       2.2
# 2         Alaska  2009      56.7        4.2      10.1       0.0       5.6
# 3        Arizona  2009      53.8        6.9      15.5       2.0       1.7
# 4       Arkansas  2009      54.1        5.8      11.8       3.6       1.5
#
#    Uninsured  Total
# 0       18.3  100.0
# 1       18.2  100.0
# 2       22.7  100.0
# 3       20.1  100.0
# 4       23.1  100.0

# %% [markdown]
# #### US insurance coverage 2011 : Health Insurance Coverage of Females 19-64 [source](https://www.kff.org/other/state-indicator/health-insurance-coverage-of-nonelderly-adult-females/?currentTimeframe=8&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D)

# %%
ins_df_2011
# Out:
#                 Location  Employer  Non-Group  Medicaid  Medicare  Military  \
# 0          United States     0.586      0.064     0.125     0.019     0.015
# 1                Alabama     0.569      0.066     0.113     0.037     0.023
# 2                 Alaska     0.574      0.028     0.113       NaN     0.050
# 3                Arizona     0.520      0.067     0.173     0.020     0.018
# 4               Arkansas     0.532      0.056     0.120     0.034     0.016
# 5             California     0.537      0.078     0.137     0.012     0.010
# 6               Colorado     0.594      0.094     0.095     0.014     0.026
# 7            Connecticut     0.675      0.063     0.143     0.015     0.006
# 8               Delaware     0.646      0.045     0.166     0.025     0.011
# 9   District of Columbia     0.611      0.063     0.230       NaN     0.008
# 10               Florida     0.513      0.076     0.102     0.021     0.019
# 11               Georgia     0.556      0.057     0.093     0.018     0.025
# 12                Hawaii     0.668      0.045     0.121     0.013     0.070
# 13                 Idaho     0.558      0.105     0.097     0.012     0.019
# 14              Illinois     0.619      0.061     0.133     0.017     0.006
# 15               Indiana     0.617      0.052     0.113     0.020     0.009
# 16                  Iowa     0.674      0.077     0.109     0.013     0.006
# 17                Kansas     0.642      0.074     0.071     0.017     0.026
# 18              Kentucky     0.571      0.054     0.134     0.029     0.016
# 19             Louisiana     0.521      0.067     0.134     0.020     0.014
# 20                 Maine     0.583      0.056     0.193     0.019     0.016
# 21              Maryland     0.678      0.062     0.109     0.015     0.017
# 22         Massachusetts     0.671      0.063     0.207     0.012     0.005
# 23              Michigan     0.601      0.060     0.158     0.022     0.005
# 24             Minnesota     0.677      0.080     0.124     0.015     0.007
# 25           Mississippi     0.517      0.052     0.145     0.029     0.018
# 26              Missouri     0.610      0.062     0.105     0.026     0.015
# 27               Montana     0.559      0.101     0.077     0.017     0.016
# 28              Nebraska     0.625      0.102     0.080     0.011     0.027
# 29                Nevada     0.569      0.052     0.081     0.018     0.024
# 30         New Hampshire     0.715      0.053     0.066     0.024     0.008
# 31            New Jersey     0.666      0.050     0.101     0.017     0.004
# 32            New Mexico     0.485      0.059     0.153     0.018     0.026
# 33              New York     0.602      0.047     0.195     0.016     0.004
# 34        North Carolina     0.556      0.067     0.112     0.025     0.029
# 35          North Dakota     0.623      0.147     0.077     0.013     0.018
# 36                  Ohio     0.634      0.052     0.133     0.022     0.008
# 37              Oklahoma     0.552      0.051     0.098     0.031     0.026
# 38                Oregon     0.572      0.083     0.116     0.017     0.010
# 39          Pennsylvania     0.645      0.065     0.137     0.020     0.007
# 40          Rhode Island     0.632      0.048     0.149     0.022     0.013
# 41        South Carolina     0.548      0.056     0.119     0.033     0.028
# 42          South Dakota     0.606      0.100     0.079     0.026     0.027
# 43             Tennessee     0.560      0.060     0.146     0.028     0.019
# 44                 Texas     0.531      0.051     0.088     0.017     0.019
# 45                  Utah     0.642      0.076     0.086     0.010     0.008
# 46               Vermont     0.640      0.058     0.207     0.017     0.011
# 47              Virginia     0.644      0.064     0.066     0.023     0.048
# 48            Washington     0.597      0.079     0.100     0.016     0.028
# 49         West Virginia     0.564      0.028     0.140     0.037     0.009
# 50             Wisconsin     0.657      0.058     0.157     0.015     0.007
# 51               Wyoming     0.629      0.079     0.070     0.015     0.022
# 52           Puerto Rico     0.333      0.106     0.441     0.041     0.004
#
#     Uninsured  Total  Footnotes
# 0       0.191    1.0        1.0
# 1       0.192    1.0        NaN
# 2       0.227    1.0        NaN
# 3       0.202    1.0        NaN
# 4       0.241    1.0        NaN
# 5       0.226    1.0        NaN
# 6       0.177    1.0        NaN
# 7       0.098    1.0        NaN
# 8       0.106    1.0        NaN
# 9       0.079    1.0        NaN
# 10      0.269    1.0        NaN
# 11      0.250    1.0        NaN
# 12      0.083    1.0        NaN
# 13      0.208    1.0        NaN
# 14      0.164    1.0        NaN
# 15      0.188    1.0        NaN
# 16      0.120    1.0        NaN
# 17      0.171    1.0        NaN
# 18      0.195    1.0        NaN
# 19      0.244    1.0        NaN
# 20      0.133    1.0        NaN
# 21      0.118    1.0        NaN
# 22      0.043    1.0        NaN
# 23      0.154    1.0        NaN
# 24      0.097    1.0        NaN
# 25      0.239    1.0        NaN
# 26      0.182    1.0        NaN
# 27      0.230    1.0        NaN
# 28      0.156    1.0        NaN
# 29      0.255    1.0        NaN
# 30      0.134    1.0        NaN
# 31      0.163    1.0        NaN
# 32      0.259    1.0        NaN
# 33      0.135    1.0        NaN
# 34      0.210    1.0        NaN
# 35      0.121    1.0        NaN
# 36      0.151    1.0        NaN
# 37      0.241    1.0        NaN
# 38      0.202    1.0        NaN
# 39      0.126    1.0        NaN
# 40      0.135    1.0        NaN
# 41      0.216    1.0        NaN
# 42      0.162    1.0        NaN
# 43      0.187    1.0        NaN
# 44      0.294    1.0        NaN
# 45      0.179    1.0        NaN
# 46      0.066    1.0        NaN
# 47      0.155    1.0        NaN
# 48      0.179    1.0        NaN
# 49      0.222    1.0        NaN
# 50      0.106    1.0        NaN
# 51      0.185    1.0        NaN
# 52      0.076    1.0        NaN
